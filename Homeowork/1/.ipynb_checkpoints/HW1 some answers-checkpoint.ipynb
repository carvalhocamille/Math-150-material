# %%
#Recommanded libraries to import at the beginning of each Jupyter notebook
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading file data

# %%
file = 'hw1_data.csv'
df = pd.read_csv(file)
t = df.iloc[:,0]
x = df.iloc[:,1]
x0 = df.iloc[:,2]
fig, ax = plt.subplots()
ax.plot(t,x,'x', t, x0,'o')

# %% [markdown]
# ### Analyze error
