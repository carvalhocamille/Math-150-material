# %%
import numpy as np
import pandas as pd
from matplotlib.pyplot import plot as plt
# %matplotlib inline

# %%
file = 'hw2_data.csv'
df = pd.read_csv(file)
#data = np.loadtxt(file)

# %%
t = df.iloc[:,0]
x = df.iloc[:,1]

# %%
plt(t,x,'x')

# %%
df
# Out:
#        0  1.9831
# 0    0.1  2.1331
# 1    0.2  2.1406
# 2    0.3  2.3278
# 3    0.4  2.3661
# 4    0.5  2.4747
# 5    0.6  2.5995
# 6    0.7  2.5937
# 7    0.8  2.6938
# 8    0.9  2.7827
# 9    1.0  2.9060
# 10   1.1  2.9939
# 11   1.2  2.9635
# 12   1.3  3.0492
# 13   1.4  3.1499
# 14   1.5  3.1715
# 15   1.6  3.3162
# 16   1.7  3.3520
# 17   1.8  3.3891
# 18   1.9  3.4570
# 19   2.0  3.6415
# 20   2.1  3.6602
# 21   2.2  3.6798
# 22   2.3  3.8179
# 23   2.4  3.7190
# 24   2.5  3.8928
# 25   2.6  3.9411
# 26   2.7  3.9550
# 27   2.8  3.9258
# 28   2.9  4.0526
# 29   3.0  4.0347
# ..   ...     ...
# 70   7.1  4.9386
# 71   7.2  4.8247
# 72   7.3  4.9293
# 73   7.4  4.9019
# 74   7.5  4.8681
# 75   7.6  4.7912
# 76   7.7  4.9721
# 77   7.8  4.8683
# 78   7.9  4.9391
# 79   8.0  4.9761
# 80   8.1  4.8236
# 81   8.2  4.8330
# 82   8.3  4.9405
# 83   8.4  4.9281
# 84   8.5  5.0314
# 85   8.6  5.0120
# 86   8.7  4.9991
# 87   8.8  4.8332
# 88   8.9  4.8411
# 89   9.0  4.8475
# ...

# %%
plt('')

# %%
np.genfromtxt()

# %%
data = np.loadtxt(file, delimiter=',')

# %%
data
# Out:
# array([[ 0.    ,  1.9831],
#        [ 0.1   ,  2.1331],
#        [ 0.2   ,  2.1406],
#        [ 0.3   ,  2.3278],
#        [ 0.4   ,  2.3661],
#        [ 0.5   ,  2.4747],
#        [ 0.6   ,  2.5995],
#        [ 0.7   ,  2.5937],
#        [ 0.8   ,  2.6938],
#        [ 0.9   ,  2.7827],
#        [ 1.    ,  2.906 ],
#        [ 1.1   ,  2.9939],
#        [ 1.2   ,  2.9635],
#        [ 1.3   ,  3.0492],
#        [ 1.4   ,  3.1499],
#        [ 1.5   ,  3.1715],
#        [ 1.6   ,  3.3162],
#        [ 1.7   ,  3.352 ],
#        [ 1.8   ,  3.3891],
#        [ 1.9   ,  3.457 ],
#        [ 2.    ,  3.6415],
#        [ 2.1   ,  3.6602],
#        [ 2.2   ,  3.6798],
#        [ 2.3   ,  3.8179],
#        [ 2.4   ,  3.719 ],
#        [ 2.5   ,  3.8928],
#        [ 2.6   ,  3.9411],
#        [ 2.7   ,  3.955 ],
#        [ 2.8   ,  3.9258],
#        [ 2.9   ,  4.0526],
#        [ 3.    ,  4.0347],
#        [ 3.1   ,  4.041 ],
#        [ 3.2   ,  4.0958],
#        [ 3.3   ,  4.276 ],
# ...

# %%
plt(*data.T,'x')
